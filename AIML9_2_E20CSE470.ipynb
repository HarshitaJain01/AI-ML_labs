# %%
import numpy as np
import pandas as pd
from sklearn import preprocessing
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix
from sklearn.metrics import precision_score, recall_score, f1_score, accuracy_score
from sklearn.metrics import roc_curve
from sklearn.metrics import auc
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("Bank Customer Churn Prediction.csv")
df.shape
# Out:
# (10000, 12)

# %%
df.head(10)
# Out:
#    customer_id  credit_score  country  gender  age  tenure    balance  \
# 0     15634602           619   France  Female   42       2       0.00
# 1     15647311           608    Spain  Female   41       1   83807.86
# 2     15619304           502   France  Female   42       8  159660.80
# 3     15701354           699   France  Female   39       1       0.00
# 4     15737888           850    Spain  Female   43       2  125510.82
# 5     15574012           645    Spain    Male   44       8  113755.78
# 6     15592531           822   France    Male   50       7       0.00
# 7     15656148           376  Germany  Female   29       4  115046.74
# 8     15792365           501   France    Male   44       4  142051.07
# 9     15592389           684   France    Male   27       2  134603.88
#
#    products_number  credit_card  active_member  estimated_salary  churn
# 0                1            1              1         101348.88      1
# 1                1            0              1         112542.58      0
# 2                3            1              0         113931.57      1
# 3                2            0              0          93826.63      0
# 4                1            1              1          79084.10      0
# 5                2            1              0         149756.71      1
# 6                2            1              1          10062.80      0
# 7                4            1              0         119346.88      1
# 8                2            0              1          74940.50      0
# 9                1            1              1          71725.73      0

# %%
df.columns
# Out:
# Index(['customer_id', 'credit_score', 'country', 'gender', 'age', 'tenure',
#        'balance', 'products_number', 'credit_card', 'active_member',
#        'estimated_salary', 'churn'],
#       dtype='object')

# %%
df.isnull().sum()
# Out:
# customer_id         0
# credit_score        0
# country             0
# gender              0
# age                 0
# tenure              0
# balance             0
# products_number     0
# credit_card         0
# active_member       0
# estimated_salary    0
# churn               0
# dtype: int64

# %%
label_encoder = preprocessing.LabelEncoder()
for x in ['country','gender']:
  df[x]= label_encoder.fit_transform(df[x])
df.head(10)
# Out:
#    customer_id  credit_score  country  gender  age  tenure    balance  \
# 0     15634602           619        0       0   42       2       0.00
# 1     15647311           608        2       0   41       1   83807.86
# 2     15619304           502        0       0   42       8  159660.80
# 3     15701354           699        0       0   39       1       0.00
# 4     15737888           850        2       0   43       2  125510.82
# 5     15574012           645        2       1   44       8  113755.78
# 6     15592531           822        0       1   50       7       0.00
# 7     15656148           376        1       0   29       4  115046.74
# 8     15792365           501        0       1   44       4  142051.07
# 9     15592389           684        0       1   27       2  134603.88
#
#    products_number  credit_card  active_member  estimated_salary  churn
# 0                1            1              1         101348.88      1
# 1                1            0              1         112542.58      0
# 2                3            1              0         113931.57      1
# 3                2            0              0          93826.63      0
# 4                1            1              1          79084.10      0
# 5                2            1              0         149756.71      1
# 6                2            1              1          10062.80      0
# 7                4            1              0         119346.88      1
# 8                2            0              1          74940.50      0
# 9                1            1              1          71725.73      0

# %%
Y = df[["churn"]].copy()
X_c = df.drop(["churn"],axis=1)

# %%
scaler = preprocessing.StandardScaler()
X = scaler.fit_transform(df.drop(["churn"],axis=1))
X = pd.DataFrame(X, columns = X_c.columns)

# %%
X_train, x_test, y_train, y_test= train_test_split(X, Y, test_size= 0.2)

# %%
from sklearn.ensemble import GradientBoostingClassifier

# %%
for x in [0.05, 0.1, 0.25, 0.5, 0.75, 1]:
  clf = GradientBoostingClassifier(n_estimators=100, learning_rate=x,max_depth=1, random_state=0).fit(X_train, y_train)
  print(clf.score(x_test, y_test))
  y_pred = clf.predict(x_test)
  print("Accuracy :",accuracy_score(y_test, y_pred))
  print("Confusion matrix :",confusion_matrix(y_test, y_pred))
  print("Precision_score : ",precision_score(y_test, y_pred, average="macro"))
  print("Recall : ",recall_score(y_test, y_pred, average="macro"))
  print("F1 score : ",f1_score(y_test, y_pred, average="macro"))

  fpr, tpr, thresholds = roc_curve(y_test, y_pred)
  roc_auc = auc(fpr, tpr)

# Plot ROC curve
  plt.plot(fpr, tpr, label='ROC curve (area = %0.3f)' % roc_auc)
  plt.plot([0, 1], [0, 1], 'k--')  # random predictions curve
  plt.xlim([0.0, 1.0])
  plt.ylim([0.0, 1.0])
  plt.xlabel('False Positive Rate or (1 - Specifity)')
  plt.ylabel('True Positive Rate or (Sensitivity)')
  plt.title('Receiver Operating Characteristic')
  plt.legend(loc="lower right")

  print("      \n")
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/ensemble/_gb.py:494: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# 0.8095
# Accuracy : 0.8095
# Confusion matrix : [[1560    4]
#  [ 377   59]]
# Precision_score :  0.8709385320123575
# Recall :  0.566381778080199
# F1 score :  0.563823448095849
# /usr/local/lib/python3.7/dist-packages/sklearn/ensemble/_gb.py:494: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# 0.842
# Accuracy : 0.842
# Confusion matrix : [[1527   37]
#  [ 279  157]]
# Precision_score :  0.8273966503407885
# Recall :  0.6682172270583542
# F1 score :  0.7023220762093165
# /usr/local/lib/python3.7/dist-packages/sklearn/ensemble/_gb.py:494: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# 0.8475
# Accuracy : 0.8475
# Confusion matrix : [[1509   55]
#  [ 250  186]]
# Precision_score :  0.8148290121461883
# Recall :  0.6957196320889745
# F1 score :  0.7288492406222955
# /usr/local/lib/python3.7/dist-packages/sklearn/ensemble/_gb.py:494: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# 0.8465
# Accuracy : 0.8465
# Confusion matrix : [[1495   69]
#  [ 238  198]]
# Precision_score :  0.8021194654979026
# Recall :  0.7050053966540745
# F1 score :  0.7350925946299731
# /usr/local/lib/python3.7/dist-packages/sklearn/ensemble/_gb.py:494: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# 0.846
# Accuracy : 0.846
# Confusion matrix : [[1492   72]
#  [ 236  200]]
# Precision_score :  0.7993600217864925
# Recall :  0.7063398953518384
# F1 score :  0.735705802802205
# /usr/local/lib/python3.7/dist-packages/sklearn/ensemble/_gb.py:494: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# 0.843
# Accuracy : 0.843
# Confusion matrix : [[1486   78]
#  [ 236  200]]
# Precision_score :  0.791187259251832
# Recall :  0.7044217367840635
# F1 score :  0.7323335907704531
